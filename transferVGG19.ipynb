# %% [markdown]
# # ***Deep Learning based Car Identification***
# ##### *- Automotive, Surveillance, Object Detection & Localisation*
#
# ***Project By:***<br>
# Premjeet Kumar https://www.linkedin.com/in/premjeet-kumar/<br>
# Hari Samynaath S https://www.linkedin.com/in/harinaathan/<br>
# Veena Raju https://www.linkedin.com/in/veena-raju-1b16b513b/<br>
# Javed Bhai https://www.linkedin.com/in/javedbhai/<br>
# Surabhi Joshi https://www.linkedin.com/in/surabhi-joshi-4452788/<br>
#
# ***Project For:***<br>
# Captstone project for **Post Graduate Program in Artificial Intelligence and Machine Learning**<br>
# with *GreatLakes & Texas McCombs School of Business, The University of Texas at Austin*
#
# **CONTEXT:**<br>
# Computer vision can be used to automate supervision and generate action appropriate action trigger if the event is predicted from the image of interest. For example a car moving on the road can be easily identi ied by a camera as make of the car, type, colour, number plates etc.<br><br>
# **DATA DESCRIPTION:**<br>
# The Cars dataset contains 16,185 images of 196 classes of cars. The data is split into 8,144 training images and 8,041 testing images, where each class has been split roughly in a 50-50 split. Classes are typically at the level of Make, Model, Year, e.g. 2012 Tesla Model S or 2012 BMW M3 coupe.<br>
# <br>
# ‣ *Train Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Test Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Train Annotation:* Consists of bounding box region for training images.<br>
# ‣ *Test Annotation:* Consists of bounding box region for testing images.<br>
#
# ### **MILESTONE 1:**
# ‣ *Step 1:* Import the data<br>
# ‣ *Step 2:* Map training and testing images to its classes.<br>
# ‣ *Step 3:* Map training and testing images to its annotations.<br>
# ‣ *Step 4:* Display images with bounding box<br>
# ‣ *Output:* Images mapped to its class and annotation ready to be used for deep learning<br>
#
# ### **MILESTONE 2:**
# ‣ *Input:* Output of milestone 1<br>
# ‣ *Step 1:* Design, train and test CNN models to classify the car.<br>
# ‣ *Step 2:* Design, train and test RCNN & its hybrids based object detection models to impose the bounding box or
# mask over the area of interest.<br>
# ‣ *Output:* Pickled model to be used for future prediction<br>

# %% [markdown]
# ### **Attempt of transfer learning based on VGG19**

# %%
from lib.networkPipe import Pipe
# Out:
# Metal device set to: Apple M1 Pro
# 2022-07-29 17:55:34.525461: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-29 17:55:34.525572: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
logdir = "logs"
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-b58549777fa9db67" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-b58549777fa9db67");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# define a transfer learning network mapped to our targets
def transferNET(application,input_size):    
    
    import tensorflow as tf
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input,GlobalMaxPool2D,Dense,BatchNormalization,Dropout
    
     # Random consistency seed
    tf.random.set_seed(100)
    
    # load application
    tNet = application(input_shape=input_size[1:],include_top=False, weights='imagenet')
    
    # flatten with pooling
    pool = GlobalMaxPool2D(name="CustomLayerStart")(tNet.output)
    
    # classifier branch for car names
    nameBranch = Dense(512,activation='relu')(pool)
    Nbn1 = BatchNormalization()(nameBranch)
    Ndo1 = Dropout(0.3)(Nbn1)
    Nhid1 = Dense(256,activation='relu')(Ndo1)
    Nbn2 = BatchNormalization()(Nhid1)
    Ndo2 = Dropout(0.3)(Nbn2)
    classifier = Dense(196,activation='softmax',name="names")(Ndo2)
    
    # regression branch for bounding boxes
    boxBranch = Dense(64,activation='relu')(pool)
    Bbn1 = BatchNormalization()(boxBranch)
    Bdo1 = Dropout(0.3)(Bbn1)
    Bhid1 = Dense(32,activation='relu')(Bdo1)
    Bbn2 = BatchNormalization()(Bhid1)
    Bdo2 = Dropout(0.3)(Bbn2)
    bBox = Dense(4,activation='relu',name="boxes")(Bdo2)
    
    # assemble the network
    model = Model(inputs=tNet.inputs,outputs=[classifier,bBox])
    
    # freeze application layers and open classifer & regressor for training
    for layer in model.layers[:-15]:
        layer.trainable = False
    
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg19 import VGG19

# %%
gPoint = {'width':224,
          'optimizer':Adam,
          'patience':5,'slope':0.3,'factor':0.1,
          'unFreezeRatio':None,
          'learning_rate':1e-3,'lossBalance':0.5}

# %%
# generator parameters
dims = (gPoint.get('width'),gPoint.get('width'))
gParams = dict(target_size=dims,batch_size=32)
# model creation parameters
mParams = dict(application=VGG19)
# optimiser for compilation
optim = gPoint.get('optimizer')
# lr scheduler parameters
lrParams = dict(patience=gPoint.get('patience'),slope=gPoint.get('slope'),factor=gPoint.get('factor'))
# earlyStop parameters
eSparams = dict(patience=int(gPoint.get('patience')*3.1),slope=gPoint.get('slope')*0.5)
# model fitting parameters
fParams = dict(epochs=30,verbose=1)
# trainability scheduler parameters
if gPoint.get('unFreezeRatio')==None:
    trParams = dict() 
else:
    trParams = dict(uncontrolled=-15,schedule={int(gPoint.get('patience')*2.8):gPoint.get('unFreezeRatio')})
# other hyper parameters
lRate = gPoint.get('learning_rate')
lBalance = gPoint.get('lossBalance')
gridPoint = dict(learning_rate=lRate,lossWeights={'names':lBalance,'boxes':1-lBalance})

# %%
pp = Pipe(generatorParams=gParams,modelFunc=transferNET,
          modelName="VGG19",modelParams=mParams)
pp.compiler(optim=Adam(),lrScheduleParams=lrParams,eStopParams=eSparams,
            trainabilityParams=trParams,gridPoint=gridPoint,sBest=True)
pp.fit(gridPoint=gridPoint,fitParams=fParams)
pp.evaluate()
pp.save()
pp.report()
# Out:
# imScanTrain: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 53.72it/s]
# imScanTest: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 54.97it/s]
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step
# 80150528/80134624 [==============================] - 3s 0us/step
# Epoch 1/30
# 2022-07-29 17:56:04.040397: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-29 17:56:04.768053: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - ETA: 0s - loss: 5.6382 - names_loss: 5.1839 - boxes_loss: 0.4542 - names_CategoricalAccuracy: 0.0344 - names_Precision: 0.2222 - names_Recall: 2.7293e-04 - boxes_IoU: -0.0753
# 2022-07-29 17:58:50.611697: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - 186s 805ms/step - loss: 5.6382 - names_loss: 5.1839 - boxes_loss: 0.4542 - names_CategoricalAccuracy: 0.0344 - names_Precision: 0.2222 - names_Recall: 2.7293e-04 - boxes_IoU: -0.0753 - val_loss: 4.7316 - val_names_loss: 4.5453 - val_boxes_loss: 0.1863 - val_names_CategoricalAccuracy: 0.0725 - val_names_Precision: 1.0000 - val_names_Recall: 0.0012 - val_boxes_IoU: 0.1307 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 186.0715
# Epoch 2/30
# 229/229 [==============================] - 185s 807ms/step - loss: 4.0741 - names_loss: 3.8663 - boxes_loss: 0.2077 - names_CategoricalAccuracy: 0.1561 - names_Precision: 0.6091 - names_Recall: 0.0091 - boxes_IoU: -0.0151 - val_loss: 4.0404 - val_names_loss: 3.9557 - val_boxes_loss: 0.0846 - val_names_CategoricalAccuracy: 0.1512 - val_names_Precision: 0.6364 - val_names_Recall: 0.0175 - val_boxes_IoU: 0.2202 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 184.5370
# Epoch 3/30
# 229/229 [==============================] - 187s 818ms/step - loss: 3.2348 - names_loss: 3.1546 - boxes_loss: 0.0802 - names_CategoricalAccuracy: 0.2774 - names_Precision: 0.7413 - names_Recall: 0.0434 - boxes_IoU: 0.3303 - val_loss: 3.9274 - val_names_loss: 3.8997 - val_boxes_loss: 0.0277 - val_names_CategoricalAccuracy: 0.1688 - val_names_Precision: 0.5205 - val_names_Recall: 0.0475 - val_boxes_IoU: 0.5198 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 187.1379
# Epoch 4/30
# 229/229 [==============================] - 188s 823ms/step - loss: 2.7386 - names_loss: 2.7021 - boxes_loss: 0.0365 - names_CategoricalAccuracy: 0.3609 - names_Precision: 0.7770 - names_Recall: 0.0932 - boxes_IoU: 0.4704 - val_loss: 3.8444 - val_names_loss: 3.8214 - val_boxes_loss: 0.0229 - val_names_CategoricalAccuracy: 0.1662 - val_names_Precision: 0.4314 - val_names_Recall: 0.0550 - val_boxes_IoU: 0.5553 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 188.2074
# Epoch 5/30
# 229/229 [==============================] - 188s 819ms/step - loss: 2.3809 - names_loss: 2.3542 - boxes_loss: 0.0267 - names_CategoricalAccuracy: 0.4281 - names_Precision: 0.8153 - names_Recall: 0.1657 - boxes_IoU: 0.5251 - val_loss: 3.4681 - val_names_loss: 3.4467 - val_boxes_loss: 0.0213 - val_names_CategoricalAccuracy: 0.2237 - val_names_Precision: 0.5851 - val_names_Recall: 0.0688 - val_boxes_IoU: 0.5743 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 187.4261
# Epoch 6/30
# 229/229 [==============================] - 185s 810ms/step - loss: 2.1290 - names_loss: 2.1060 - boxes_loss: 0.0231 - names_CategoricalAccuracy: 0.4752 - names_Precision: 0.8281 - names_Recall: 0.2254 - boxes_IoU: 0.5542 - val_loss: 3.5390 - val_names_loss: 3.5193 - val_boxes_loss: 0.0198 - val_names_CategoricalAccuracy: 0.2188 - val_names_Precision: 0.4398 - val_names_Recall: 0.0912 - val_boxes_IoU: 0.5825 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 185.3876
# Epoch 7/30
# 229/229 [==============================] - 182s 794ms/step - loss: 1.9153 - names_loss: 1.8950 - boxes_loss: 0.0203 - names_CategoricalAccuracy: 0.5278 - names_Precision: 0.8262 - names_Recall: 0.2784 - boxes_IoU: 0.5759 - val_loss: 3.6207 - val_names_loss: 3.6034 - val_boxes_loss: 0.0173 - val_names_CategoricalAccuracy: 0.2075 - val_names_Precision: 0.5030 - val_names_Recall: 0.1037 - val_boxes_IoU: 0.6030 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 181.6786
# Epoch 8/30
# 229/229 [==============================] - 183s 799ms/step - loss: 1.5237 - names_loss: 1.5045 - boxes_loss: 0.0192 - names_CategoricalAccuracy: 0.6198 - names_Precision: 0.8877 - names_Recall: 0.3710 - boxes_IoU: 0.5848 - val_loss: 3.0686 - val_names_loss: 3.0514 - val_boxes_loss: 0.0172 - val_names_CategoricalAccuracy: 0.2875 - val_names_Precision: 0.6375 - val_names_Recall: 0.1275 - val_boxes_IoU: 0.6042 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 182.8120
# Epoch 9/30
# 229/229 [==============================] - 182s 795ms/step - loss: 1.4235 - names_loss: 1.4045 - boxes_loss: 0.0190 - names_CategoricalAccuracy: 0.6472 - names_Precision: 0.9069 - names_Recall: 0.4039 - boxes_IoU: 0.5854 - val_loss: 3.0006 - val_names_loss: 2.9837 - val_boxes_loss: 0.0170 - val_names_CategoricalAccuracy: 0.3025 - val_names_Precision: 0.6497 - val_names_Recall: 0.1437 - val_boxes_IoU: 0.6053 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 182.0578
# Epoch 10/30
# 229/229 [==============================] - 184s 802ms/step - loss: 1.3675 - names_loss: 1.3488 - boxes_loss: 0.0187 - names_CategoricalAccuracy: 0.6582 - names_Precision: 0.9076 - names_Recall: 0.4170 - boxes_IoU: 0.5891 - val_loss: 3.0042 - val_names_loss: 2.9876 - val_boxes_loss: 0.0165 - val_names_CategoricalAccuracy: 0.3012 - val_names_Precision: 0.6647 - val_names_Recall: 0.1437 - val_boxes_IoU: 0.6094 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 183.7638
# Epoch 11/30
# 229/229 [==============================] - 184s 804ms/step - loss: 1.3161 - names_loss: 1.2977 - boxes_loss: 0.0183 - names_CategoricalAccuracy: 0.6782 - names_Precision: 0.9065 - names_Recall: 0.4352 - boxes_IoU: 0.5912 - val_loss: 3.0173 - val_names_loss: 3.0011 - val_boxes_loss: 0.0161 - val_names_CategoricalAccuracy: 0.2900 - val_names_Precision: 0.6420 - val_names_Recall: 0.1412 - val_boxes_IoU: 0.6130 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 184.0762
# Epoch 12/30
# 229/229 [==============================] - 184s 802ms/step - loss: 1.2736 - names_loss: 1.2555 - boxes_loss: 0.0181 - names_CategoricalAccuracy: 0.6901 - names_Precision: 0.9141 - names_Recall: 0.4445 - boxes_IoU: 0.5930 - val_loss: 3.0021 - val_names_loss: 2.9861 - val_boxes_loss: 0.0160 - val_names_CategoricalAccuracy: 0.3000 - val_names_Precision: 0.6514 - val_names_Recall: 0.1425 - val_boxes_IoU: 0.6140 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 183.6885
# Epoch 13/30
# 229/229 [==============================] - 183s 801ms/step - loss: 1.2635 - names_loss: 1.2455 - boxes_loss: 0.0180 - names_CategoricalAccuracy: 0.6844 - names_Precision: 0.9242 - names_Recall: 0.4576 - boxes_IoU: 0.5952 - val_loss: 2.9780 - val_names_loss: 2.9622 - val_boxes_loss: 0.0159 - val_names_CategoricalAccuracy: 0.3000 - val_names_Precision: 0.6494 - val_names_Recall: 0.1412 - val_boxes_IoU: 0.6146 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 183.3359
# Epoch 14/30
# 229/229 [==============================] - 184s 802ms/step - loss: 1.2792 - names_loss: 1.2611 - boxes_loss: 0.0181 - names_CategoricalAccuracy: 0.6865 - names_Precision: 0.9208 - names_Recall: 0.4427 - boxes_IoU: 0.5881 - val_loss: 2.9914 - val_names_loss: 2.9753 - val_boxes_loss: 0.0160 - val_names_CategoricalAccuracy: 0.3000 - val_names_Precision: 0.6298 - val_names_Recall: 0.1425 - val_boxes_IoU: 0.6134 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 183.6243
# Epoch 15/30
# 229/229 [==============================] - 182s 797ms/step - loss: 1.2494 - names_loss: 1.2317 - boxes_loss: 0.0177 - names_CategoricalAccuracy: 0.6924 - names_Precision: 0.9148 - names_Recall: 0.4558 - boxes_IoU: 0.5959 - val_loss: 2.9861 - val_names_loss: 2.9702 - val_boxes_loss: 0.0159 - val_names_CategoricalAccuracy: 0.3012 - val_names_Precision: 0.6384 - val_names_Recall: 0.1412 - val_boxes_IoU: 0.6148 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 182.4472
# Epoch 16/30
# 229/229 [==============================] - 182s 795ms/step - loss: 1.2520 - names_loss: 1.2342 - boxes_loss: 0.0178 - names_CategoricalAccuracy: 0.6931 - names_Precision: 0.9180 - names_Recall: 0.4490 - boxes_IoU: 0.5954 - val_loss: 2.9892 - val_names_loss: 2.9732 - val_boxes_loss: 0.0160 - val_names_CategoricalAccuracy: 0.2962 - val_names_Precision: 0.6343 - val_names_Recall: 0.1388 - val_boxes_IoU: 0.6139 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 182.1320
# Epoch 17/30
# 229/229 [==============================] - 181s 791ms/step - loss: 1.2345 - names_loss: 1.2167 - boxes_loss: 0.0177 - names_CategoricalAccuracy: 0.6999 - names_Precision: 0.9228 - names_Recall: 0.4567 - boxes_IoU: 0.5972 - val_loss: 2.9805 - val_names_loss: 2.9647 - val_boxes_loss: 0.0158 - val_names_CategoricalAccuracy: 0.3113 - val_names_Precision: 0.6541 - val_names_Recall: 0.1512 - val_boxes_IoU: 0.6155 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 181.2036
# Epoch 18/30
# 229/229 [==============================] - 185s 806ms/step - loss: 1.2324 - names_loss: 1.2145 - boxes_loss: 0.0178 - names_CategoricalAccuracy: 0.6956 - names_Precision: 0.9163 - names_Recall: 0.4496 - boxes_IoU: 0.5942 - val_loss: 2.9893 - val_names_loss: 2.9733 - val_boxes_loss: 0.0160 - val_names_CategoricalAccuracy: 0.3050 - val_names_Precision: 0.6480 - val_names_Recall: 0.1450 - val_boxes_IoU: 0.6129 - learning_rate: 1.0000e-06 - Trainable: 15.0000 - lapTime: 184.7349
# Epoch 19/30
# 229/229 [==============================] - ETA: 0s - loss: 1.2494 - names_loss: 1.2317 - boxes_loss: 0.0177 - names_CategoricalAccuracy: 0.6951 - names_Precision: 0.9191 - names_Recall: 0.4558 - boxes_IoU: 0.5962
#
# ---------------------------------------------------------------
# eStop initiated after epoch  18 for poor loss gradient of 0.136
# ---------------------------------------------------------------
#
# 229/229 [==============================] - 186s 813ms/step - loss: 1.2494 - names_loss: 1.2317 - boxes_loss: 0.0177 - names_CategoricalAccuracy: 0.6951 - names_Precision: 0.9191 - names_Recall: 0.4558 - boxes_IoU: 0.5962 - val_loss: 2.9955 - val_names_loss: 2.9797 - val_boxes_loss: 0.0158 - val_names_CategoricalAccuracy: 0.3037 - val_names_Precision: 0.6517 - val_names_Recall: 0.1450 - val_boxes_IoU: 0.6156 - learning_rate: 1.0000e-06 - Trainable: 15.0000 - lapTime: 185.9741
#
# ----------
# EVALUATION
# ----------
#
# 254/254 [==============================] - 181s 714ms/step - loss: 0.9525 - names_loss: 0.9370 - boxes_loss: 0.0155 - names_CategoricalAccuracy: 0.8381 - names_Precision: 0.9808 - names_Recall: 0.6045 - boxes_IoU: 0.6182
# 251/251 [==============================] - 177s 707ms/step - loss: 3.0307 - names_loss: 3.0154 - boxes_loss: 0.0153 - names_CategoricalAccuracy: 0.3039 - names_Precision: 0.6265 - names_Recall: 0.1360 - boxes_IoU: 0.6200
# 2022-07-29 19:00:25.752672: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./deployables/VGG19/VGG19/tfsave/assets
#     name target_size batch_size optimizer patience slope factor learning_rate  \
# 0  VGG19  (224, 224)         32      Adam       15  0.15    0.1         0.001
#
#                     lossWeights epochs verbose  \
# 0  {'names': 0.5, 'boxes': 0.5}     30       1
#
#                                                 logs     loss names_loss  \
# 0  {'loss': [5.638175010681152, 4.074068546295166...  0.95251   0.937004
#
#   boxes_loss names_CategoricalAccuracy names_Precision names_Recall boxes_IoU  \
# 0   0.015506                  0.838091        0.980834     0.604454  0.618246
#
#    val_loss val_names_loss val_boxes_loss val_names_CategoricalAccuracy  \
# 0  3.030715       3.015413       0.015301                      0.303909
#
#   val_names_Precision val_names_Recall val_boxes_IoU
# 0            0.626506         0.135956      0.620036
# ----------
# PREDICTION
# ----------
# 2022-07-29 19:00:29.147484: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 254/254 [==============================] - 179s 706ms/step
# 251/251 [==============================] - 177s 705ms/step
# samples from TRAINING SET
# samples from TESTING SET
