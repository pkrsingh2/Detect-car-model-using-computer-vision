# %% [markdown]
# # ***Deep Learning based Car Identification***
# ##### *- Automotive, Surveillance, Object Detection & Localisation*
#
# ***Project By:***<br>
# Premjeet Kumar https://www.linkedin.com/in/premjeet-kumar/<br>
# Hari Samynaath S https://www.linkedin.com/in/harinaathan/<br>
# Veena Raju https://www.linkedin.com/in/veena-raju-1b16b513b/<br>
# Javed Bhai https://www.linkedin.com/in/javedbhai/<br>
# Surabhi Joshi https://www.linkedin.com/in/surabhi-joshi-4452788/<br>
#
# ***Project For:***<br>
# Captstone project for **Post Graduate Program in Artificial Intelligence and Machine Learning**<br>
# with *GreatLakes & Texas McCombs School of Business, The University of Texas at Austin*
#
# **CONTEXT:**<br>
# Computer vision can be used to automate supervision and generate action appropriate action trigger if the event is predicted from the image of interest. For example a car moving on the road can be easily identi ied by a camera as make of the car, type, colour, number plates etc.<br><br>
# **DATA DESCRIPTION:**<br>
# The Cars dataset contains 16,185 images of 196 classes of cars. The data is split into 8,144 training images and 8,041 testing images, where each class has been split roughly in a 50-50 split. Classes are typically at the level of Make, Model, Year, e.g. 2012 Tesla Model S or 2012 BMW M3 coupe.<br>
# <br>
# ‣ *Train Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Test Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Train Annotation:* Consists of bounding box region for training images.<br>
# ‣ *Test Annotation:* Consists of bounding box region for testing images.<br>
#
# ### **MILESTONE 1:**
# ‣ *Step 1:* Import the data<br>
# ‣ *Step 2:* Map training and testing images to its classes.<br>
# ‣ *Step 3:* Map training and testing images to its annotations.<br>
# ‣ *Step 4:* Display images with bounding box<br>
# ‣ *Output:* Images mapped to its class and annotation ready to be used for deep learning<br>
#
# ### **MILESTONE 2:**
# ‣ *Input:* Output of milestone 1<br>
# ‣ *Step 1:* Design, train and test CNN models to classify the car.<br>
# ‣ *Step 2:* Design, train and test RCNN & its hybrids based object detection models to impose the bounding box or
# mask over the area of interest.<br>
# ‣ *Output:* Pickled model to be used for future prediction<br>

# %% [markdown]
# ### **Attempt of transfer learning based on NASNetMobile**

# %%
from lib.networkPipe import Pipe
# Out:
# Metal device set to: Apple M1 Pro
# 2022-07-29 16:46:25.057348: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-29 16:46:25.057462: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
logdir = "logs"
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-185e1f05b65c29d2" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-185e1f05b65c29d2");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# define a transfer learning network mapped to our targets
def transferNET(application,input_size):    
    
    import tensorflow as tf
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input,GlobalMaxPool2D,Dense,BatchNormalization,Dropout
    
     # Random consistency seed
    tf.random.set_seed(100)
    
    # load application
    tNet = application(input_shape=input_size[1:],include_top=False, weights='imagenet')
    
    # flatten with pooling
    pool = GlobalMaxPool2D(name="CustomLayerStart")(tNet.output)
    
    # classifier branch for car names
    nameBranch = Dense(512,activation='relu')(pool)
    Nbn1 = BatchNormalization()(nameBranch)
    Ndo1 = Dropout(0.3)(Nbn1)
    Nhid1 = Dense(256,activation='relu')(Ndo1)
    Nbn2 = BatchNormalization()(Nhid1)
    Ndo2 = Dropout(0.3)(Nbn2)
    classifier = Dense(196,activation='softmax',name="names")(Ndo2)
    
    # regression branch for bounding boxes
    boxBranch = Dense(64,activation='relu')(pool)
    Bbn1 = BatchNormalization()(boxBranch)
    Bdo1 = Dropout(0.3)(Bbn1)
    Bhid1 = Dense(32,activation='relu')(Bdo1)
    Bbn2 = BatchNormalization()(Bhid1)
    Bdo2 = Dropout(0.3)(Bbn2)
    bBox = Dense(4,activation='relu',name="boxes")(Bdo2)
    
    # assemble the network
    model = Model(inputs=tNet.inputs,outputs=[classifier,bBox])
    
    # freeze application layers and open classifer & regressor for training
    for layer in model.layers[:-15]:
        layer.trainable = False
    
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.nasnet import NASNetMobile

# %%
gPoint = {'width':224,
          'optimizer':Adam,
          'patience':5,'slope':0.3,'factor':0.1,
          'unFreezeRatio':None,
          'learning_rate':1e-3,'lossBalance':0.5}

# %%
# generator parameters
dims = (gPoint.get('width'),gPoint.get('width'))
gParams = dict(target_size=dims,batch_size=32)
# model creation parameters
mParams = dict(application=NASNetMobile)
# optimiser for compilation
optim = gPoint.get('optimizer')
# lr scheduler parameters
lrParams = dict(patience=gPoint.get('patience'),slope=gPoint.get('slope'),factor=gPoint.get('factor'))
# earlyStop parameters
eSparams = dict(patience=int(gPoint.get('patience')*3.1),slope=gPoint.get('slope')*0.5)
# model fitting parameters
fParams = dict(epochs=30,verbose=1)
# trainability scheduler parameters
if gPoint.get('unFreezeRatio')==None:
    trParams = dict() 
else:
    trParams = dict(uncontrolled=-15,schedule={int(gPoint.get('patience')*2.8):gPoint.get('unFreezeRatio')})
# other hyper parameters
lRate = gPoint.get('learning_rate')
lBalance = gPoint.get('lossBalance')
gridPoint = dict(learning_rate=lRate,lossWeights={'names':lBalance,'boxes':1-lBalance})

# %%
pp = Pipe(generatorParams=gParams,modelFunc=transferNET,
          modelName="NASNetMobile",modelParams=mParams)
pp.compiler(optim=Adam(),lrScheduleParams=lrParams,eStopParams=eSparams,
            trainabilityParams=trParams,gridPoint=gridPoint,sBest=True)
pp.fit(gridPoint=gridPoint,fitParams=fParams)
pp.evaluate()
pp.save()
pp.report()
# Out:
# imScanTrain: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 54.99it/s]
# imScanTest: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 55.14it/s]
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19996672/19993432 [==============================] - 1s 0us/step
# 20004864/19993432 [==============================] - 1s 0us/step
# Epoch 1/30
# 2022-07-29 16:46:56.075621: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-29 16:47:01.339503: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#   6/229 [..............................] - ETA: 1:36 - loss: 6.7492 - names_loss: 5.8331 - boxes_loss: 0.9161 - names_CategoricalAccuracy: 0.0104 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: -0.0928   WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4252s vs `on_train_batch_end` time: 1.3715s). Check your callbacks.
# 229/229 [==============================] - ETA: 0s - loss: 4.9830 - names_loss: 4.6173 - boxes_loss: 0.3657 - names_CategoricalAccuracy: 0.0590 - names_Precision: 0.2697 - names_Recall: 0.0056 - boxes_IoU: -0.9186
# 2022-07-29 16:49:17.559699: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - 161s 634ms/step - loss: 4.9830 - names_loss: 4.6173 - boxes_loss: 0.3657 - names_CategoricalAccuracy: 0.0590 - names_Precision: 0.2697 - names_Recall: 0.0056 - boxes_IoU: -0.9186 - val_loss: 3.9399 - val_names_loss: 3.8123 - val_boxes_loss: 0.1275 - val_names_CategoricalAccuracy: 0.1100 - val_names_Precision: 0.4062 - val_names_Recall: 0.0162 - val_boxes_IoU: 0.2624 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 160.3005
# Epoch 2/30
# 229/229 [==============================] - 147s 639ms/step - loss: 3.8665 - names_loss: 3.7121 - boxes_loss: 0.1544 - names_CategoricalAccuracy: 0.1332 - names_Precision: 0.4382 - names_Recall: 0.0160 - boxes_IoU: 0.2154 - val_loss: 3.6554 - val_names_loss: 3.6166 - val_boxes_loss: 0.0388 - val_names_CategoricalAccuracy: 0.1512 - val_names_Precision: 0.2787 - val_names_Recall: 0.0213 - val_boxes_IoU: 0.4835 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 145.6646
# Epoch 3/30
# 229/229 [==============================] - 146s 639ms/step - loss: 3.3679 - names_loss: 3.3019 - boxes_loss: 0.0660 - names_CategoricalAccuracy: 0.1975 - names_Precision: 0.5465 - names_Recall: 0.0321 - boxes_IoU: 0.3822 - val_loss: 3.4099 - val_names_loss: 3.3879 - val_boxes_loss: 0.0220 - val_names_CategoricalAccuracy: 0.1538 - val_names_Precision: 0.5000 - val_names_Recall: 0.0250 - val_boxes_IoU: 0.5620 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 145.5813
# Epoch 4/30
# 229/229 [==============================] - 148s 648ms/step - loss: 3.0069 - names_loss: 2.9706 - boxes_loss: 0.0363 - names_CategoricalAccuracy: 0.2522 - names_Precision: 0.6277 - names_Recall: 0.0557 - boxes_IoU: 0.4813 - val_loss: 3.2569 - val_names_loss: 3.2392 - val_boxes_loss: 0.0177 - val_names_CategoricalAccuracy: 0.2050 - val_names_Precision: 0.5205 - val_names_Recall: 0.0475 - val_boxes_IoU: 0.5919 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 147.5931
# Epoch 5/30
# 229/229 [==============================] - 146s 639ms/step - loss: 2.7542 - names_loss: 2.7291 - boxes_loss: 0.0251 - names_CategoricalAccuracy: 0.3053 - names_Precision: 0.6394 - names_Recall: 0.0842 - boxes_IoU: 0.5347 - val_loss: 3.2067 - val_names_loss: 3.1921 - val_boxes_loss: 0.0146 - val_names_CategoricalAccuracy: 0.2037 - val_names_Precision: 0.5747 - val_names_Recall: 0.0625 - val_boxes_IoU: 0.6229 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 145.6211
# Epoch 6/30
# 229/229 [==============================] - 146s 638ms/step - loss: 2.5175 - names_loss: 2.4976 - boxes_loss: 0.0200 - names_CategoricalAccuracy: 0.3484 - names_Precision: 0.6992 - names_Recall: 0.1202 - boxes_IoU: 0.5706 - val_loss: 3.3065 - val_names_loss: 3.2934 - val_boxes_loss: 0.0131 - val_names_CategoricalAccuracy: 0.2200 - val_names_Precision: 0.5487 - val_names_Recall: 0.0775 - val_boxes_IoU: 0.6368 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 146.2446
# Epoch 7/30
# 229/229 [==============================] - 142s 619ms/step - loss: 2.3096 - names_loss: 2.2929 - boxes_loss: 0.0167 - names_CategoricalAccuracy: 0.3896 - names_Precision: 0.7047 - names_Recall: 0.1576 - boxes_IoU: 0.6001 - val_loss: 3.2168 - val_names_loss: 3.2055 - val_boxes_loss: 0.0112 - val_names_CategoricalAccuracy: 0.2338 - val_names_Precision: 0.4524 - val_names_Recall: 0.0950 - val_boxes_IoU: 0.6596 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 141.8451
# Epoch 8/30
# 229/229 [==============================] - 143s 623ms/step - loss: 1.8891 - names_loss: 1.8738 - boxes_loss: 0.0152 - names_CategoricalAccuracy: 0.5052 - names_Precision: 0.8207 - names_Recall: 0.2317 - boxes_IoU: 0.6130 - val_loss: 2.8649 - val_names_loss: 2.8537 - val_boxes_loss: 0.0112 - val_names_CategoricalAccuracy: 0.2900 - val_names_Precision: 0.6378 - val_names_Recall: 0.1013 - val_boxes_IoU: 0.6559 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 141.8584
# Epoch 9/30
# 229/229 [==============================] - 143s 625ms/step - loss: 1.7480 - names_loss: 1.7336 - boxes_loss: 0.0145 - names_CategoricalAccuracy: 0.5434 - names_Precision: 0.8633 - names_Recall: 0.2688 - boxes_IoU: 0.6218 - val_loss: 2.8435 - val_names_loss: 2.8325 - val_boxes_loss: 0.0110 - val_names_CategoricalAccuracy: 0.2925 - val_names_Precision: 0.6391 - val_names_Recall: 0.1062 - val_boxes_IoU: 0.6572 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 142.4231
# Epoch 10/30
# 229/229 [==============================] - 143s 623ms/step - loss: 1.6871 - names_loss: 1.6725 - boxes_loss: 0.0146 - names_CategoricalAccuracy: 0.5565 - names_Precision: 0.8646 - names_Recall: 0.2866 - boxes_IoU: 0.6197 - val_loss: 2.8171 - val_names_loss: 2.8062 - val_boxes_loss: 0.0109 - val_names_CategoricalAccuracy: 0.3063 - val_names_Precision: 0.6190 - val_names_Recall: 0.1137 - val_boxes_IoU: 0.6582 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 141.8516
# Epoch 11/30
# 229/229 [==============================] - 142s 618ms/step - loss: 1.6232 - names_loss: 1.6088 - boxes_loss: 0.0144 - names_CategoricalAccuracy: 0.5727 - names_Precision: 0.8630 - names_Recall: 0.3034 - boxes_IoU: 0.6227 - val_loss: 2.8386 - val_names_loss: 2.8277 - val_boxes_loss: 0.0109 - val_names_CategoricalAccuracy: 0.2925 - val_names_Precision: 0.6118 - val_names_Recall: 0.1163 - val_boxes_IoU: 0.6594 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 141.5070
# Epoch 12/30
# 229/229 [==============================] - 142s 621ms/step - loss: 1.5805 - names_loss: 1.5666 - boxes_loss: 0.0139 - names_CategoricalAccuracy: 0.5865 - names_Precision: 0.8780 - names_Recall: 0.3252 - boxes_IoU: 0.6267 - val_loss: 2.8524 - val_names_loss: 2.8418 - val_boxes_loss: 0.0106 - val_names_CategoricalAccuracy: 0.2937 - val_names_Precision: 0.6226 - val_names_Recall: 0.1237 - val_boxes_IoU: 0.6647 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 142.1758
# Epoch 13/30
# 229/229 [==============================] - 142s 619ms/step - loss: 1.5151 - names_loss: 1.5015 - boxes_loss: 0.0136 - names_CategoricalAccuracy: 0.6111 - names_Precision: 0.8847 - names_Recall: 0.3330 - boxes_IoU: 0.6302 - val_loss: 2.8213 - val_names_loss: 2.8107 - val_boxes_loss: 0.0106 - val_names_CategoricalAccuracy: 0.2975 - val_names_Precision: 0.5808 - val_names_Recall: 0.1212 - val_boxes_IoU: 0.6633 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 141.9295
# Epoch 14/30
# 229/229 [==============================] - 144s 627ms/step - loss: 1.5082 - names_loss: 1.4945 - boxes_loss: 0.0137 - names_CategoricalAccuracy: 0.6105 - names_Precision: 0.8790 - names_Recall: 0.3251 - boxes_IoU: 0.6301 - val_loss: 2.8157 - val_names_loss: 2.8049 - val_boxes_loss: 0.0107 - val_names_CategoricalAccuracy: 0.2937 - val_names_Precision: 0.5765 - val_names_Recall: 0.1225 - val_boxes_IoU: 0.6621 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 142.6859
# Epoch 15/30
# 229/229 [==============================] - 146s 636ms/step - loss: 1.4941 - names_loss: 1.4804 - boxes_loss: 0.0138 - names_CategoricalAccuracy: 0.6090 - names_Precision: 0.9009 - names_Recall: 0.3386 - boxes_IoU: 0.6294 - val_loss: 2.8100 - val_names_loss: 2.7994 - val_boxes_loss: 0.0106 - val_names_CategoricalAccuracy: 0.2987 - val_names_Precision: 0.5882 - val_names_Recall: 0.1250 - val_boxes_IoU: 0.6626 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 145.1260
# Epoch 16/30
# 229/229 [==============================] - 143s 622ms/step - loss: 1.4888 - names_loss: 1.4750 - boxes_loss: 0.0137 - names_CategoricalAccuracy: 0.6186 - names_Precision: 0.8896 - names_Recall: 0.3399 - boxes_IoU: 0.6292 - val_loss: 2.8228 - val_names_loss: 2.8121 - val_boxes_loss: 0.0106 - val_names_CategoricalAccuracy: 0.2950 - val_names_Precision: 0.5868 - val_names_Recall: 0.1225 - val_boxes_IoU: 0.6622 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 142.8198
# Epoch 17/30
# 229/229 [==============================] - 147s 640ms/step - loss: 1.4978 - names_loss: 1.4841 - boxes_loss: 0.0137 - names_CategoricalAccuracy: 0.6066 - names_Precision: 0.8899 - names_Recall: 0.3386 - boxes_IoU: 0.6307 - val_loss: 2.8131 - val_names_loss: 2.8025 - val_boxes_loss: 0.0106 - val_names_CategoricalAccuracy: 0.3000 - val_names_Precision: 0.5977 - val_names_Recall: 0.1300 - val_boxes_IoU: 0.6636 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 146.7526
# Epoch 18/30
# 229/229 [==============================] - ETA: 0s - loss: 1.4878 - names_loss: 1.4742 - boxes_loss: 0.0136 - names_CategoricalAccuracy: 0.6120 - names_Precision: 0.8937 - names_Recall: 0.3420 - boxes_IoU: 0.6301
#
# ---------------------------------------------------------------
# eStop initiated after epoch  17 for poor loss gradient of 0.132
# ---------------------------------------------------------------
#
# 229/229 [==============================] - 151s 660ms/step - loss: 1.4878 - names_loss: 1.4742 - boxes_loss: 0.0136 - names_CategoricalAccuracy: 0.6120 - names_Precision: 0.8937 - names_Recall: 0.3420 - boxes_IoU: 0.6301 - val_loss: 2.8261 - val_names_loss: 2.8154 - val_boxes_loss: 0.0107 - val_names_CategoricalAccuracy: 0.2937 - val_names_Precision: 0.5988 - val_names_Recall: 0.1250 - val_boxes_IoU: 0.6622 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 151.2552
#
# ----------
# EVALUATION
# ----------
#
# 254/254 [==============================] - 138s 544ms/step - loss: 1.2693 - names_loss: 1.2589 - boxes_loss: 0.0104 - names_CategoricalAccuracy: 0.7287 - names_Precision: 0.9582 - names_Recall: 0.4142 - boxes_IoU: 0.6676
# 251/251 [==============================] - 135s 540ms/step - loss: 2.8155 - names_loss: 2.8048 - boxes_loss: 0.0107 - names_CategoricalAccuracy: 0.3052 - names_Precision: 0.6398 - names_Recall: 0.1174 - boxes_IoU: 0.6658
# 2022-07-29 17:35:26.368408: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./deployables/NASNetMobile/NASNetMobile/tfsave/assets
#            name target_size batch_size optimizer patience slope factor  \
# 0  NASNetMobile  (224, 224)         32      Adam       15  0.15    0.1
#
#   learning_rate                   lossWeights epochs verbose  \
# 0         0.001  {'names': 0.5, 'boxes': 0.5}     30       1
#
#                                                 logs      loss names_loss  \
# 0  {'loss': [4.982983589172363, 3.866465091705322...  1.269307   1.258898
#
#   boxes_loss names_CategoricalAccuracy names_Precision names_Recall boxes_IoU  \
# 0   0.010408                  0.728716        0.958167     0.414247  0.667567
#
#    val_loss val_names_loss val_boxes_loss val_names_CategoricalAccuracy  \
# 0  2.815521        2.80481        0.01071                      0.305154
#
#   val_names_Precision val_names_Recall val_boxes_IoU
# 0            0.639756         0.117405      0.665775
# ----------
# PREDICTION
# ----------
# 2022-07-29 17:36:06.299654: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 254/254 [==============================] - 138s 534ms/step
# 251/251 [==============================] - 134s 535ms/step
# samples from TRAINING SET
# samples from TESTING SET
