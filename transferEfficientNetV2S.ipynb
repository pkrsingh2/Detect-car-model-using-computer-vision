# %% [markdown]
# # ***Deep Learning based Car Identification***
# ##### *- Automotive, Surveillance, Object Detection & Localisation*
#
# ***Project By:***<br>
# Premjeet Kumar https://www.linkedin.com/in/premjeet-kumar/<br>
# Hari Samynaath S https://www.linkedin.com/in/harinaathan/<br>
# Veena Raju https://www.linkedin.com/in/veena-raju-1b16b513b/<br>
# Javed Bhai https://www.linkedin.com/in/javedbhai/<br>
# Surabhi Joshi https://www.linkedin.com/in/surabhi-joshi-4452788/<br>
#
# ***Project For:***<br>
# Captstone project for **Post Graduate Program in Artificial Intelligence and Machine Learning**<br>
# with *GreatLakes & Texas McCombs School of Business, The University of Texas at Austin*
#
# **CONTEXT:**<br>
# Computer vision can be used to automate supervision and generate action appropriate action trigger if the event is predicted from the image of interest. For example a car moving on the road can be easily identi ied by a camera as make of the car, type, colour, number plates etc.<br><br>
# **DATA DESCRIPTION:**<br>
# The Cars dataset contains 16,185 images of 196 classes of cars. The data is split into 8,144 training images and 8,041 testing images, where each class has been split roughly in a 50-50 split. Classes are typically at the level of Make, Model, Year, e.g. 2012 Tesla Model S or 2012 BMW M3 coupe.<br>
# <br>
# ‣ *Train Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Test Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Train Annotation:* Consists of bounding box region for training images.<br>
# ‣ *Test Annotation:* Consists of bounding box region for testing images.<br>
#
# ### **MILESTONE 1:**
# ‣ *Step 1:* Import the data<br>
# ‣ *Step 2:* Map training and testing images to its classes.<br>
# ‣ *Step 3:* Map training and testing images to its annotations.<br>
# ‣ *Step 4:* Display images with bounding box<br>
# ‣ *Output:* Images mapped to its class and annotation ready to be used for deep learning<br>
#
# ### **MILESTONE 2:**
# ‣ *Input:* Output of milestone 1<br>
# ‣ *Step 1:* Design, train and test CNN models to classify the car.<br>
# ‣ *Step 2:* Design, train and test RCNN & its hybrids based object detection models to impose the bounding box or
# mask over the area of interest.<br>
# ‣ *Output:* Pickled model to be used for future prediction<br>

# %% [markdown]
# ### **Attempt of transfer learning based on EfficientNetV2S**

# %%
from lib.networkPipe import Pipe
# Out:
# Metal device set to: Apple M1 Pro
# 2022-07-29 12:21:08.516539: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-29 12:21:08.516645: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
logdir = "logs"
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-f15b49fd967b4095" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f15b49fd967b4095");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# define a transfer learning network mapped to our targets
def transferNET(application,input_size):    
    
    import tensorflow as tf
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input,GlobalMaxPool2D,Dense,BatchNormalization,Dropout
    
     # Random consistency seed
    tf.random.set_seed(100)
    
    # load application
    tNet = application(input_shape=input_size[1:],include_top=False, weights='imagenet')
    
    # flatten with pooling
    pool = GlobalMaxPool2D(name="CustomLayerStart")(tNet.output)
    
    # classifier branch for car names
    nameBranch = Dense(512,activation='relu')(pool)
    Nbn1 = BatchNormalization()(nameBranch)
    Ndo1 = Dropout(0.3)(Nbn1)
    Nhid1 = Dense(256,activation='relu')(Ndo1)
    Nbn2 = BatchNormalization()(Nhid1)
    Ndo2 = Dropout(0.3)(Nbn2)
    classifier = Dense(196,activation='softmax',name="names")(Ndo2)
    
    # regression branch for bounding boxes
    boxBranch = Dense(64,activation='relu')(pool)
    Bbn1 = BatchNormalization()(boxBranch)
    Bdo1 = Dropout(0.3)(Bbn1)
    Bhid1 = Dense(32,activation='relu')(Bdo1)
    Bbn2 = BatchNormalization()(Bhid1)
    Bdo2 = Dropout(0.3)(Bbn2)
    bBox = Dense(4,activation='relu',name="boxes")(Bdo2)
    
    # assemble the network
    model = Model(inputs=tNet.inputs,outputs=[classifier,bBox])
    
    # freeze application layers and open classifer & regressor for training
    for layer in model.layers[:-15]:
        layer.trainable = False
    
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.efficientnet_v2 import EfficientNetV2S

# %%
gPoint = {'width':224,
          'optimizer':Adam,
          'patience':5,'slope':0.3,'factor':0.1,
          'unFreezeRatio':None,
          'learning_rate':1e-3,'lossBalance':0.5}

# %%
# generator parameters
dims = (gPoint.get('width'),gPoint.get('width'))
gParams = dict(target_size=dims,batch_size=32)
# model creation parameters
mParams = dict(application=EfficientNetV2S)
# optimiser for compilation
optim = gPoint.get('optimizer')
# lr scheduler parameters
lrParams = dict(patience=gPoint.get('patience'),slope=gPoint.get('slope'),factor=gPoint.get('factor'))
# earlyStop parameters
eSparams = dict(patience=int(gPoint.get('patience')*3.1),slope=gPoint.get('slope')*0.5)
# model fitting parameters
fParams = dict(epochs=30,verbose=1)
# trainability scheduler parameters
if gPoint.get('unFreezeRatio')==None:
    trParams = dict() 
else:
    trParams = dict(uncontrolled=-15,schedule={int(gPoint.get('patience')*2.8):gPoint.get('unFreezeRatio')})
# other hyper parameters
lRate = gPoint.get('learning_rate')
lBalance = gPoint.get('lossBalance')
gridPoint = dict(learning_rate=lRate,lossWeights={'names':lBalance,'boxes':1-lBalance})

# %%
pp = Pipe(generatorParams=gParams,modelFunc=transferNET,
          modelName="EfficientNetV2S",modelParams=mParams)
pp.compiler(optim=Adam(),lrScheduleParams=lrParams,eStopParams=eSparams,
            trainabilityParams=trParams,gridPoint=gridPoint,sBest=True)
pp.fit(gridPoint=gridPoint,fitParams=fParams)
pp.evaluate()
pp.save()
pp.report()
# Out:
# imScanTrain: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 54.01it/s]
# imScanTest: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 54.81it/s]
# Epoch 1/30
# 2022-07-29 12:21:41.933436: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-29 12:21:46.539685: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#   6/229 [..............................] - ETA: 1:39 - loss: 6.9519 - names_loss: 6.0398 - boxes_loss: 0.9121 - names_CategoricalAccuracy: 0.0052 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 3.4002WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.4394s vs `on_train_batch_end` time: 1.2606s). Check your callbacks.
# 229/229 [==============================] - ETA: 0s - loss: 5.9727 - names_loss: 5.6556 - boxes_loss: 0.3171 - names_CategoricalAccuracy: 0.0075 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.2920
# 2022-07-29 12:24:10.046241: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
#
- learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 155.3911
# Epoch 9/30
# 229/229 [==============================] - 155s 675ms/step - loss: 5.1397 - names_loss: 5.1060 - boxes_loss: 0.0337 - names_CategoricalAccuracy: 0.0220 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5191 - val_loss: 5.4952 - val_names_loss: 5.4666 - val_boxes_loss: 0.0286 - val_names_CategoricalAccuracy: 0.0100 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4983 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 154.6735
# Epoch 10/30
# 229/229 [==============================] - 153s 669ms/step - loss: 5.1411 - names_loss: 5.1082 - boxes_loss: 0.0329 - names_CategoricalAccuracy: 0.0224 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5238 - val_loss: 5.4608 - val_names_loss: 5.4306 - val_boxes_loss: 0.0302 - val_names_CategoricalAccuracy: 0.0088 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4886 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 153.2178
# Epoch 11/30
# 229/229 [==============================] - 153s 668ms/step - loss: 5.1117 - names_loss: 5.0785 - boxes_loss: 0.0331 - names_CategoricalAccuracy: 0.0242 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5219 - val_loss: 5.2394 - val_names_loss: 5.2106 - val_boxes_loss: 0.0288 - val_names_CategoricalAccuracy: 0.0137 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4988 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 152.4832
# Epoch 12/30
# 229/229 [==============================] - 155s 675ms/step - loss: 5.0964 - names_loss: 5.0639 - boxes_loss: 0.0325 - names_CategoricalAccuracy: 0.0246 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5233 - val_loss: 5.2276 - val_names_loss: 5.1993 - val_boxes_loss: 0.0283 - val_names_CategoricalAccuracy: 0.0200 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.5024 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 153.9102
# Epoch 13/30
# 229/229 [==============================] - 154s 672ms/step - loss: 5.1077 - names_loss: 5.0758 - boxes_loss: 0.0319 - names_CategoricalAccuracy: 0.0224 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5256 - val_loss: 5.2258 - val_names_loss: 5.1973 - val_boxes_loss: 0.0284 - val_names_CategoricalAccuracy: 0.0225 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.5018 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 153.2991
# Epoch 14/30
# 229/229 [==============================] - 154s 672ms/step - loss: 5.1015 - names_loss: 5.0694 - boxes_loss: 0.0320 - names_CategoricalAccuracy: 0.0240 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5256 - val_loss: 5.2230 - val_names_loss: 5.1944 - val_boxes_loss: 0.0286 - val_names_CategoricalAccuracy: 0.0187 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4989 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 153.2520
# Epoch 15/30
# 229/229 [==============================] - 154s 673ms/step - loss: 5.1075 - names_loss: 5.0754 - boxes_loss: 0.0321 - names_CategoricalAccuracy: 0.0239 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5261 - val_loss: 5.2205 - val_names_loss: 5.1920 - val_boxes_loss: 0.0285 - val_names_CategoricalAccuracy: 0.0213 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.5009 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 153.5691
# Epoch 16/30
# 229/229 [==============================] - 156s 681ms/step - loss: 5.0965 - names_loss: 5.0645 - boxes_loss: 0.0320 - names_CategoricalAccuracy: 0.0254 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5261 - val_loss: 5.2258 - val_names_loss: 5.1968 - val_boxes_loss: 0.0290 - val_names_CategoricalAccuracy: 0.0162 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4955 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 156.1129
# Epoch 17/30
# 229/229 [==============================] - 156s 682ms/step - loss: 5.0988 - names_loss: 5.0667 - boxes_loss: 0.0321 - names_CategoricalAccuracy: 0.0248 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5256 - val_loss: 5.2129 - val_names_loss: 5.1841 - val_boxes_loss: 0.0288 - val_names_CategoricalAccuracy: 0.0175 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4994 - learning_rate: 1.0000e-06 - Trainable: 15.0000 - lapTime: 155.7169
# Epoch 18/30
# 229/229 [==============================] - 156s 681ms/step - loss: 5.0958 - names_loss: 5.0640 - boxes_loss: 0.0318 - names_CategoricalAccuracy: 0.0251 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5246 - val_loss: 5.2189 - val_names_loss: 5.1897 - val_boxes_loss: 0.0293 - val_names_CategoricalAccuracy: 0.0187 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.4938 - learning_rate: 1.0000e-06 - Trainable: 15.0000 - lapTime: 156.2048
# Epoch 19/30
# 229/229 [==============================] - ETA: 0s - loss: 5.0934 - names_loss: 5.0617 - boxes_loss: 0.0318 - names_CategoricalAccuracy: 0.0224 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5277
#
# ---------------------------------------------------------------
# eStop initiated after epoch  18 for poor loss gradient of 0.067
# ---------------------------------------------------------------
#
# 229/229 [==============================] - 156s 683ms/step - loss: 5.0934 - names_loss: 5.0617 - boxes_loss: 0.0318 - names_CategoricalAccuracy: 0.0224 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5277 - val_loss: 5.2158 - val_names_loss: 5.1876 - val_boxes_loss: 0.0283 - val_names_CategoricalAccuracy: 0.0175 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: 0.5031 - learning_rate: 1.0000e-06 - Trainable: 15.0000 - lapTime: 156.3817
#
# ----------
# EVALUATION
# ----------
#
# 254/254 [==============================] - 151s 596ms/step - loss: 4.9835 - names_loss: 4.9557 - boxes_loss: 0.0277 - names_CategoricalAccuracy: 0.0370 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5117
# 251/251 [==============================] - 150s 599ms/step - loss: 5.2454 - names_loss: 5.2180 - boxes_loss: 0.0274 - names_CategoricalAccuracy: 0.0164 - names_Precision: 0.0000e+00 - names_Recall: 0.0000e+00 - boxes_IoU: 0.5148
# 2022-07-29 13:15:56.251144: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./deployables/EfficientNetV2S/EfficientNetV2S/tfsave/assets
#               name target_size batch_size optimizer patience slope factor  \
# 0  EfficientNetV2S  (224, 224)         32      Adam       15  0.15    0.1
#
#   learning_rate                   lossWeights epochs verbose  \
# 0         0.001  {'names': 0.5, 'boxes': 0.5}     30       1
#
#                                                 logs      loss names_loss  \
# 0  {'loss': [5.972702503204346, 5.568402290344238...  4.983481    4.95574
#
#   boxes_loss names_CategoricalAccuracy names_Precision names_Recall boxes_IoU  \
# 0   0.027741                  0.037032             0.0          0.0  0.511724
#
#    val_loss val_names_loss val_boxes_loss val_names_CategoricalAccuracy  \
# 0  5.245408       5.218029        0.02738                      0.016434
#
#   val_names_Precision val_names_Recall val_boxes_IoU
# 0                 0.0              0.0      0.514779
# ----------
# PREDICTION
# ----------
# 2022-07-29 13:16:37.203934: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 254/254 [==============================] - 150s 581ms/step
# 251/251 [==============================] - 146s 584ms/step
# samples from TRAINING SET
# samples from TESTING SET
