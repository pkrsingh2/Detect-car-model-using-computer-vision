# %% [markdown]
# # ***Deep Learning based Car Identification***
# ##### *- Automotive, Surveillance, Object Detection & Localisation*
#
# ***Project By:***<br>
# Premjeet Kumar https://www.linkedin.com/in/premjeet-kumar/<br>
# Hari Samynaath S https://www.linkedin.com/in/harinaathan/<br>
# Veena Raju https://www.linkedin.com/in/veena-raju-1b16b513b/<br>
# Javed Bhai https://www.linkedin.com/in/javedbhai/<br>
# Surabhi Joshi https://www.linkedin.com/in/surabhi-joshi-4452788/<br>
#
# ***Project For:***<br>
# Captstone project for **Post Graduate Program in Artificial Intelligence and Machine Learning**<br>
# with *GreatLakes & Texas McCombs School of Business, The University of Texas at Austin*
#
# **CONTEXT:**<br>
# Computer vision can be used to automate supervision and generate action appropriate action trigger if the event is predicted from the image of interest. For example a car moving on the road can be easily identi ied by a camera as make of the car, type, colour, number plates etc.<br><br>
# **DATA DESCRIPTION:**<br>
# The Cars dataset contains 16,185 images of 196 classes of cars. The data is split into 8,144 training images and 8,041 testing images, where each class has been split roughly in a 50-50 split. Classes are typically at the level of Make, Model, Year, e.g. 2012 Tesla Model S or 2012 BMW M3 coupe.<br>
# <br>
# ‣ *Train Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Test Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Train Annotation:* Consists of bounding box region for training images.<br>
# ‣ *Test Annotation:* Consists of bounding box region for testing images.<br>
#
# ### **MILESTONE 1:**
# ‣ *Step 1:* Import the data<br>
# ‣ *Step 2:* Map training and testing images to its classes.<br>
# ‣ *Step 3:* Map training and testing images to its annotations.<br>
# ‣ *Step 4:* Display images with bounding box<br>
# ‣ *Output:* Images mapped to its class and annotation ready to be used for deep learning<br>
#
# ### **MILESTONE 2:**
# ‣ *Input:* Output of milestone 1<br>
# ‣ *Step 1:* Design, train and test CNN models to classify the car.<br>
# ‣ *Step 2:* Design, train and test RCNN & its hybrids based object detection models to impose the bounding box or
# mask over the area of interest.<br>
# ‣ *Output:* Pickled model to be used for future prediction<br>

# %% [markdown]
# ### **Attempt of transfer learning based on VGG16**

# %%
from lib.networkPipe import Pipe
# Out:
# Metal device set to: Apple M1 Pro
# 2022-07-29 14:45:17.073654: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-29 14:45:17.073760: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
logdir = "logs"
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-6b90e06d731fb774" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-6b90e06d731fb774");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# define a transfer learning network mapped to our targets
def transferNET(application,input_size):    
    
    import tensorflow as tf
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input,GlobalMaxPool2D,Dense,BatchNormalization,Dropout
    
     # Random consistency seed
    tf.random.set_seed(100)
    
    # load application
    tNet = application(input_shape=input_size[1:],include_top=False, weights='imagenet')
    
    # flatten with pooling
    pool = GlobalMaxPool2D(name="CustomLayerStart")(tNet.output)
    
    # classifier branch for car names
    nameBranch = Dense(512,activation='relu')(pool)
    Nbn1 = BatchNormalization()(nameBranch)
    Ndo1 = Dropout(0.3)(Nbn1)
    Nhid1 = Dense(256,activation='relu')(Ndo1)
    Nbn2 = BatchNormalization()(Nhid1)
    Ndo2 = Dropout(0.3)(Nbn2)
    classifier = Dense(196,activation='softmax',name="names")(Ndo2)
    
    # regression branch for bounding boxes
    boxBranch = Dense(64,activation='relu')(pool)
    Bbn1 = BatchNormalization()(boxBranch)
    Bdo1 = Dropout(0.3)(Bbn1)
    Bhid1 = Dense(32,activation='relu')(Bdo1)
    Bbn2 = BatchNormalization()(Bhid1)
    Bdo2 = Dropout(0.3)(Bbn2)
    bBox = Dense(4,activation='relu',name="boxes")(Bdo2)
    
    # assemble the network
    model = Model(inputs=tNet.inputs,outputs=[classifier,bBox])
    
    # freeze application layers and open classifer & regressor for training
    for layer in model.layers[:-15]:
        layer.trainable = False
    
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.vgg16 import VGG16

# %%
gPoint = {'width':224,
          'optimizer':Adam,
          'patience':5,'slope':0.3,'factor':0.1,
          'unFreezeRatio':None,
          'learning_rate':1e-3,'lossBalance':0.5}

# %%
# generator parameters
dims = (gPoint.get('width'),gPoint.get('width'))
gParams = dict(target_size=dims,batch_size=32)
# model creation parameters
mParams = dict(application=VGG16)
# optimiser for compilation
optim = gPoint.get('optimizer')
# lr scheduler parameters
lrParams = dict(patience=gPoint.get('patience'),slope=gPoint.get('slope'),factor=gPoint.get('factor'))
# earlyStop parameters
eSparams = dict(patience=int(gPoint.get('patience')*3.1),slope=gPoint.get('slope')*0.5)
# model fitting parameters
fParams = dict(epochs=30,verbose=1)
# trainability scheduler parameters
if gPoint.get('unFreezeRatio')==None:
    trParams = dict() 
else:
    trParams = dict(uncontrolled=-15,schedule={int(gPoint.get('patience')*2.8):gPoint.get('unFreezeRatio')})
# other hyper parameters
lRate = gPoint.get('learning_rate')
lBalance = gPoint.get('lossBalance')
gridPoint = dict(learning_rate=lRate,lossWeights={'names':lBalance,'boxes':1-lBalance})

# %%
pp = Pipe(generatorParams=gParams,modelFunc=transferNET,
          modelName="VGG16",modelParams=mParams)
pp.compiler(optim=Adam(),lrScheduleParams=lrParams,eStopParams=eSparams,
            trainabilityParams=trParams,gridPoint=gridPoint,sBest=True)
pp.fit(gridPoint=gridPoint,fitParams=fParams)
pp.evaluate()
pp.save()
pp.report()
# Out:
# imScanTrain: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 53.72it/s]
# imScanTest: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 55.27it/s]
# Epoch 1/30
# 2022-07-29 14:45:43.952438: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-29 14:45:44.724196: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - ETA: 0s - loss: 5.5871 - names_loss: 5.1350 - boxes_loss: 0.4521 - names_CategoricalAccuracy: 0.0386 - names_Precision: 0.4286 - names_Recall: 0.0012 - boxes_IoU: -0.0014
# 2022-07-29 14:48:17.303676: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - 172s 741ms/step - loss: 5.5871 - names_loss: 5.1350 - boxes_loss: 0.4521 - names_CategoricalAccuracy: 0.0386 - names_Precision: 0.4286 - names_Recall: 0.0012 - boxes_IoU: -0.0014 - val_loss: 4.6942 - val_names_loss: 4.4184 - val_boxes_loss: 0.2759 - val_names_CategoricalAccuracy: 0.0875 - val_names_Precision: 0.0000e+00 - val_names_Recall: 0.0000e+00 - val_boxes_IoU: -0.0060 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 171.5402
# Epoch 2/30
# 229/229 [==============================] - 169s 736ms/step - loss: 3.9664 - names_loss: 3.7354 - boxes_loss: 0.2309 - names_CategoricalAccuracy: 0.1745 - names_Precision: 0.6503 - names_Recall: 0.0145 - boxes_IoU: 0.0156 - val_loss: 3.8791 - val_names_loss: 3.7747 - val_boxes_loss: 0.1043 - val_names_CategoricalAccuracy: 0.1587 - val_names_Precision: 0.6842 - val_names_Recall: 0.0162 - val_boxes_IoU: 0.2246 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 168.4589
# Epoch 3/30
# 229/229 [==============================] - 167s 730ms/step - loss: 3.1274 - names_loss: 3.0283 - boxes_loss: 0.0991 - names_CategoricalAccuracy: 0.2941 - names_Precision: 0.7911 - names_Recall: 0.0532 - boxes_IoU: 0.2874 - val_loss: 3.5683 - val_names_loss: 3.5387 - val_boxes_loss: 0.0296 - val_names_CategoricalAccuracy: 0.1937 - val_names_Precision: 0.6500 - val_names_Recall: 0.0487 - val_boxes_IoU: 0.5060 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 166.9786
# Epoch 4/30
# 229/229 [==============================] - 168s 734ms/step - loss: 2.6267 - names_loss: 2.5804 - boxes_loss: 0.0463 - names_CategoricalAccuracy: 0.3788 - names_Precision: 0.7998 - names_Recall: 0.1139 - boxes_IoU: 0.4377 - val_loss: 3.5070 - val_names_loss: 3.4836 - val_boxes_loss: 0.0234 - val_names_CategoricalAccuracy: 0.2013 - val_names_Precision: 0.5412 - val_names_Recall: 0.0575 - val_boxes_IoU: 0.5553 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 167.9897
# Epoch 5/30
# 229/229 [==============================] - 169s 736ms/step - loss: 2.2990 - names_loss: 2.2671 - boxes_loss: 0.0319 - names_CategoricalAccuracy: 0.4397 - names_Precision: 0.8029 - names_Recall: 0.1724 - boxes_IoU: 0.5053 - val_loss: 3.4244 - val_names_loss: 3.4042 - val_boxes_loss: 0.0202 - val_names_CategoricalAccuracy: 0.2075 - val_names_Precision: 0.4160 - val_names_Recall: 0.0650 - val_boxes_IoU: 0.5837 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 168.4576
# Epoch 6/30
# 229/229 [==============================] - 167s 728ms/step - loss: 2.0355 - names_loss: 2.0108 - boxes_loss: 0.0247 - names_CategoricalAccuracy: 0.4872 - names_Precision: 0.8207 - names_Recall: 0.2448 - boxes_IoU: 0.5400 - val_loss: 3.5562 - val_names_loss: 3.5384 - val_boxes_loss: 0.0178 - val_names_CategoricalAccuracy: 0.2150 - val_names_Precision: 0.3918 - val_names_Recall: 0.0837 - val_boxes_IoU: 0.6048 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 166.6333
# Epoch 7/30
# 229/229 [==============================] - 167s 730ms/step - loss: 1.8221 - names_loss: 1.8018 - boxes_loss: 0.0204 - names_CategoricalAccuracy: 0.5385 - names_Precision: 0.8290 - names_Recall: 0.3036 - boxes_IoU: 0.5708 - val_loss: 3.7612 - val_names_loss: 3.7468 - val_boxes_loss: 0.0144 - val_names_CategoricalAccuracy: 0.1975 - val_names_Precision: 0.3594 - val_names_Recall: 0.0975 - val_boxes_IoU: 0.6332 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 166.9648
# Epoch 8/30
# 229/229 [==============================] - 168s 733ms/step - loss: 1.4388 - names_loss: 1.4199 - boxes_loss: 0.0189 - names_CategoricalAccuracy: 0.6347 - names_Precision: 0.8807 - names_Recall: 0.3951 - boxes_IoU: 0.5828 - val_loss: 2.8959 - val_names_loss: 2.8810 - val_boxes_loss: 0.0149 - val_names_CategoricalAccuracy: 0.2950 - val_names_Precision: 0.6340 - val_names_Recall: 0.1212 - val_boxes_IoU: 0.6296 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 167.7846
# Epoch 9/30
# 229/229 [==============================] - 168s 732ms/step - loss: 1.3371 - names_loss: 1.3185 - boxes_loss: 0.0185 - names_CategoricalAccuracy: 0.6668 - names_Precision: 0.9042 - names_Recall: 0.4367 - boxes_IoU: 0.5860 - val_loss: 2.8669 - val_names_loss: 2.8521 - val_boxes_loss: 0.0148 - val_names_CategoricalAccuracy: 0.2912 - val_names_Precision: 0.6384 - val_names_Recall: 0.1412 - val_boxes_IoU: 0.6322 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 167.4893
# Epoch 10/30
# 229/229 [==============================] - 168s 736ms/step - loss: 1.2752 - names_loss: 1.2566 - boxes_loss: 0.0186 - names_CategoricalAccuracy: 0.6910 - names_Precision: 0.9140 - names_Recall: 0.4498 - boxes_IoU: 0.5858 - val_loss: 2.8377 - val_names_loss: 2.8233 - val_boxes_loss: 0.0144 - val_names_CategoricalAccuracy: 0.2987 - val_names_Precision: 0.5858 - val_names_Recall: 0.1237 - val_boxes_IoU: 0.6353 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 168.2587
# Epoch 11/30
# 229/229 [==============================] - 168s 734ms/step - loss: 1.2220 - names_loss: 1.2042 - boxes_loss: 0.0178 - names_CategoricalAccuracy: 0.6924 - names_Precision: 0.9147 - names_Recall: 0.4653 - boxes_IoU: 0.5913 - val_loss: 2.8505 - val_names_loss: 2.8361 - val_boxes_loss: 0.0144 - val_names_CategoricalAccuracy: 0.2950 - val_names_Precision: 0.6150 - val_names_Recall: 0.1437 - val_boxes_IoU: 0.6358 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 168.0041
# Epoch 12/30
# 229/229 [==============================] - 168s 735ms/step - loss: 1.1907 - names_loss: 1.1732 - boxes_loss: 0.0175 - names_CategoricalAccuracy: 0.7119 - names_Precision: 0.9245 - names_Recall: 0.4780 - boxes_IoU: 0.5950 - val_loss: 2.8746 - val_names_loss: 2.8607 - val_boxes_loss: 0.0139 - val_names_CategoricalAccuracy: 0.2962 - val_names_Precision: 0.6250 - val_names_Recall: 0.1437 - val_boxes_IoU: 0.6397 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 168.4637
# Epoch 13/30
# 229/229 [==============================] - 168s 735ms/step - loss: 1.1650 - names_loss: 1.1477 - boxes_loss: 0.0173 - names_CategoricalAccuracy: 0.7130 - names_Precision: 0.9199 - names_Recall: 0.4939 - boxes_IoU: 0.5970 - val_loss: 2.8183 - val_names_loss: 2.8046 - val_boxes_loss: 0.0138 - val_names_CategoricalAccuracy: 0.3137 - val_names_Precision: 0.6105 - val_names_Recall: 0.1450 - val_boxes_IoU: 0.6410 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 168.1034
# Epoch 14/30
# 229/229 [==============================] - 169s 738ms/step - loss: 1.1521 - names_loss: 1.1348 - boxes_loss: 0.0173 - names_CategoricalAccuracy: 0.7155 - names_Precision: 0.9228 - names_Recall: 0.4858 - boxes_IoU: 0.5959 - val_loss: 2.8348 - val_names_loss: 2.8211 - val_boxes_loss: 0.0137 - val_names_CategoricalAccuracy: 0.3037 - val_names_Precision: 0.5979 - val_names_Recall: 0.1412 - val_boxes_IoU: 0.6412 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 168.8482
# Epoch 15/30
# 229/229 [==============================] - 168s 734ms/step - loss: 1.1470 - names_loss: 1.1296 - boxes_loss: 0.0174 - names_CategoricalAccuracy: 0.7227 - names_Precision: 0.9229 - names_Recall: 0.4903 - boxes_IoU: 0.5969 - val_loss: 2.8329 - val_names_loss: 2.8193 - val_boxes_loss: 0.0135 - val_names_CategoricalAccuracy: 0.3075 - val_names_Precision: 0.5946 - val_names_Recall: 0.1375 - val_boxes_IoU: 0.6433 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 168.0084
# Epoch 16/30
# 229/229 [==============================] - 171s 748ms/step - loss: 1.1356 - names_loss: 1.1185 - boxes_loss: 0.0171 - names_CategoricalAccuracy: 0.7267 - names_Precision: 0.9294 - names_Recall: 0.4990 - boxes_IoU: 0.5979 - val_loss: 2.8327 - val_names_loss: 2.8190 - val_boxes_loss: 0.0137 - val_names_CategoricalAccuracy: 0.3088 - val_names_Precision: 0.5914 - val_names_Recall: 0.1375 - val_boxes_IoU: 0.6421 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 171.2428
# Epoch 17/30
# 229/229 [==============================] - 169s 740ms/step - loss: 1.1285 - names_loss: 1.1114 - boxes_loss: 0.0171 - names_CategoricalAccuracy: 0.7275 - names_Precision: 0.9245 - names_Recall: 0.4999 - boxes_IoU: 0.5942 - val_loss: 2.8241 - val_names_loss: 2.8106 - val_boxes_loss: 0.0136 - val_names_CategoricalAccuracy: 0.3100 - val_names_Precision: 0.5957 - val_names_Recall: 0.1400 - val_boxes_IoU: 0.6436 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 169.3356
# Epoch 18/30
# 229/229 [==============================] - 167s 731ms/step - loss: 1.1354 - names_loss: 1.1184 - boxes_loss: 0.0170 - names_CategoricalAccuracy: 0.7231 - names_Precision: 0.9235 - names_Recall: 0.4962 - boxes_IoU: 0.6002 - val_loss: 2.8270 - val_names_loss: 2.8136 - val_boxes_loss: 0.0135 - val_names_CategoricalAccuracy: 0.3075 - val_names_Precision: 0.5926 - val_names_Recall: 0.1400 - val_boxes_IoU: 0.6441 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 167.3550
# Epoch 19/30
# 229/229 [==============================] - 167s 731ms/step - loss: 1.1170 - names_loss: 1.1001 - boxes_loss: 0.0168 - names_CategoricalAccuracy: 0.7258 - names_Precision: 0.9291 - names_Recall: 0.5008 - boxes_IoU: 0.6004 - val_loss: 2.8357 - val_names_loss: 2.8223 - val_boxes_loss: 0.0134 - val_names_CategoricalAccuracy: 0.3088 - val_names_Precision: 0.6022 - val_names_Recall: 0.1400 - val_boxes_IoU: 0.6451 - learning_rate: 1.0000e-06 - Trainable: 15.0000 - lapTime: 167.4421
# Epoch 20/30
# 229/229 [==============================] - 167s 731ms/step - loss: 1.0980 - names_loss: 1.0809 - boxes_loss: 0.0171 - names_CategoricalAccuracy: 0.7365 - names_Precision: 0.9244 - names_Recall: 0.5037 - boxes_IoU: 0.5979 - val_loss: 2.8264 - val_names_loss: 2.8128 - val_boxes_loss: 0.0136 - val_names_CategoricalAccuracy: 0.3075 - val_names_Precision: 0.6162 - val_names_Recall: 0.1425 - val_boxes_IoU: 0.6431 - learning_rate: 1.0000e-07 - Trainable: 15.0000 - lapTime: 167.3332
# Epoch 21/30
# 229/229 [==============================] - 168s 732ms/step - loss: 1.1368 - names_loss: 1.1201 - boxes_loss: 0.0167 - names_CategoricalAccuracy: 0.7253 - names_Precision: 0.9204 - names_Recall: 0.4986 - boxes_IoU: 0.6007 - val_loss: 2.8363 - val_names_loss: 2.8228 - val_boxes_loss: 0.0135 - val_names_CategoricalAccuracy: 0.3075 - val_names_Precision: 0.6011 - val_names_Recall: 0.1412 - val_boxes_IoU: 0.6439 - learning_rate: 1.0000e-07 - Trainable: 15.0000 - lapTime: 167.6105
# Epoch 22/30
# 229/229 [==============================] - ETA: 0s - loss: 1.1329 - names_loss: 1.1159 - boxes_loss: 0.0170 - names_CategoricalAccuracy: 0.7230 - names_Precision: 0.9257 - names_Recall: 0.4981 - boxes_IoU: 0.5991
#
# ---------------------------------------------------------------
# eStop initiated after epoch  21 for poor loss gradient of 0.024
# ---------------------------------------------------------------
#
# 229/229 [==============================] - 167s 729ms/step - loss: 1.1329 - names_loss: 1.1159 - boxes_loss: 0.0170 - names_CategoricalAccuracy: 0.7230 - names_Precision: 0.9257 - names_Recall: 0.4981 - boxes_IoU: 0.5991 - val_loss: 2.8259 - val_names_loss: 2.8124 - val_boxes_loss: 0.0135 - val_names_CategoricalAccuracy: 0.3063 - val_names_Precision: 0.5926 - val_names_Recall: 0.1400 - val_boxes_IoU: 0.6432 - learning_rate: 1.0000e-07 - Trainable: 15.0000 - lapTime: 166.9243
#
# ----------
# EVALUATION
# ----------
#
# 254/254 [==============================] - 164s 646ms/step - loss: 0.8442 - names_loss: 0.8310 - boxes_loss: 0.0131 - names_CategoricalAccuracy: 0.8594 - names_Precision: 0.9786 - names_Recall: 0.6567 - boxes_IoU: 0.6469
# 251/251 [==============================] - 165s 658ms/step - loss: 2.8574 - names_loss: 2.8447 - boxes_loss: 0.0126 - names_CategoricalAccuracy: 0.3271 - names_Precision: 0.6506 - names_Recall: 0.1635 - boxes_IoU: 0.6511
# 2022-07-29 15:52:55.119051: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./deployables/VGG16/VGG16/tfsave/assets
#     name target_size batch_size optimizer patience slope factor learning_rate  \
# 0  VGG16  (224, 224)         32      Adam       15  0.15    0.1         0.001
#
#                     lossWeights epochs verbose  \
# 0  {'names': 0.5, 'boxes': 0.5}     30       1
#
#                                                 logs      loss names_loss  \
# 0  {'loss': [5.587075233459473, 3.966358661651611...  0.844168   0.831028
#
#   boxes_loss names_CategoricalAccuracy names_Precision names_Recall boxes_IoU  \
# 0    0.01314                  0.859375        0.978552     0.656742  0.646943
#
#    val_loss val_names_loss val_boxes_loss val_names_CategoricalAccuracy  \
# 0  2.857366       2.844716        0.01265                      0.327067
#
#   val_names_Precision val_names_Recall val_boxes_IoU
# 0            0.650644         0.163471       0.65108
# ----------
# PREDICTION
# ----------
# 2022-07-29 15:52:58.335476: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 254/254 [==============================] - 166s 655ms/step
# 251/251 [==============================] - 164s 656ms/step
# samples from TRAINING SET
# samples from TESTING SET
