# %% [markdown]
# # ***Deep Learning based Car Identification***
# ##### *- Automotive, Surveillance, Object Detection & Localisation*
#
# ***Project By:***<br>
# Premjeet Kumar https://www.linkedin.com/in/premjeet-kumar/<br>
# Hari Samynaath S https://www.linkedin.com/in/harinaathan/<br>
# Veena Raju https://www.linkedin.com/in/veena-raju-1b16b513b/<br>
# Javed Bhai https://www.linkedin.com/in/javedbhai/<br>
# Surabhi Joshi https://www.linkedin.com/in/surabhi-joshi-4452788/<br>
#
# ***Project For:***<br>
# Captstone project for **Post Graduate Program in Artificial Intelligence and Machine Learning**<br>
# with *GreatLakes & Texas McCombs School of Business, The University of Texas at Austin*
#
# **CONTEXT:**<br>
# Computer vision can be used to automate supervision and generate action appropriate action trigger if the event is predicted from the image of interest. For example a car moving on the road can be easily identi ied by a camera as make of the car, type, colour, number plates etc.<br><br>
# **DATA DESCRIPTION:**<br>
# The Cars dataset contains 16,185 images of 196 classes of cars. The data is split into 8,144 training images and 8,041 testing images, where each class has been split roughly in a 50-50 split. Classes are typically at the level of Make, Model, Year, e.g. 2012 Tesla Model S or 2012 BMW M3 coupe.<br>
# <br>
# ‣ *Train Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Test Images:* Consists of real images of cars as per the make and year of the car.<br>
# ‣ *Train Annotation:* Consists of bounding box region for training images.<br>
# ‣ *Test Annotation:* Consists of bounding box region for testing images.<br>
#
# ### **MILESTONE 1:**
# ‣ *Step 1:* Import the data<br>
# ‣ *Step 2:* Map training and testing images to its classes.<br>
# ‣ *Step 3:* Map training and testing images to its annotations.<br>
# ‣ *Step 4:* Display images with bounding box<br>
# ‣ *Output:* Images mapped to its class and annotation ready to be used for deep learning<br>
#
# ### **MILESTONE 2:**
# ‣ *Input:* Output of milestone 1<br>
# ‣ *Step 1:* Design, train and test CNN models to classify the car.<br>
# ‣ *Step 2:* Design, train and test RCNN & its hybrids based object detection models to impose the bounding box or
# mask over the area of interest.<br>
# ‣ *Output:* Pickled model to be used for future prediction<br>

# %% [markdown]
# ### **Attempt of transfer learning based on ResNet152v2**

# %%
from lib.networkPipe import Pipe
# Out:
# Metal device set to: Apple M1 Pro
# 2022-07-29 19:07:44.369570: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-07-29 19:07:44.369682: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
logdir = "logs"
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-3b4d7d42b5e56c04" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-3b4d7d42b5e56c04");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# define a transfer learning network mapped to our targets
def transferNET(application,input_size):    
    
    import tensorflow as tf
    from tensorflow.keras.models import Model
    from tensorflow.keras.layers import Input,GlobalMaxPool2D,Dense,BatchNormalization,Dropout
    
     # Random consistency seed
    tf.random.set_seed(100)
    
    # load application
    tNet = application(input_shape=input_size[1:],include_top=False, weights='imagenet')
    
    # flatten with pooling
    pool = GlobalMaxPool2D(name="CustomLayerStart")(tNet.output)
    
    # classifier branch for car names
    nameBranch = Dense(512,activation='relu')(pool)
    Nbn1 = BatchNormalization()(nameBranch)
    Ndo1 = Dropout(0.3)(Nbn1)
    Nhid1 = Dense(256,activation='relu')(Ndo1)
    Nbn2 = BatchNormalization()(Nhid1)
    Ndo2 = Dropout(0.3)(Nbn2)
    classifier = Dense(196,activation='softmax',name="names")(Ndo2)
    
    # regression branch for bounding boxes
    boxBranch = Dense(64,activation='relu')(pool)
    Bbn1 = BatchNormalization()(boxBranch)
    Bdo1 = Dropout(0.3)(Bbn1)
    Bhid1 = Dense(32,activation='relu')(Bdo1)
    Bbn2 = BatchNormalization()(Bhid1)
    Bdo2 = Dropout(0.3)(Bbn2)
    bBox = Dense(4,activation='relu',name="boxes")(Bdo2)
    
    # assemble the network
    model = Model(inputs=tNet.inputs,outputs=[classifier,bBox])
    
    # freeze application layers and open classifer & regressor for training
    for layer in model.layers[:-15]:
        layer.trainable = False
    
    return model

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.applications.resnet_v2 import ResNet50V2

# %%
gPoint = {'width':224,
          'optimizer':Adam,
          'patience':5,'slope':0.3,'factor':0.1,
          'unFreezeRatio':None,
          'learning_rate':1e-3,'lossBalance':0.5}

# %%
# generator parameters
dims = (gPoint.get('width'),gPoint.get('width'))
gParams = dict(target_size=dims,batch_size=32)
# model creation parameters
mParams = dict(application=ResNet50V2)
# optimiser for compilation
optim = gPoint.get('optimizer')
# lr scheduler parameters
lrParams = dict(patience=gPoint.get('patience'),slope=gPoint.get('slope'),factor=gPoint.get('factor'))
# earlyStop parameters
eSparams = dict(patience=int(gPoint.get('patience')*3.1),slope=gPoint.get('slope')*0.5)
# model fitting parameters
fParams = dict(epochs=30,verbose=1)
# trainability scheduler parameters
if gPoint.get('unFreezeRatio')==None:
    trParams = dict() 
else:
    trParams = dict(uncontrolled=-15,schedule={int(gPoint.get('patience')*2.8):gPoint.get('unFreezeRatio')})
# other hyper parameters
lRate = gPoint.get('learning_rate')
lBalance = gPoint.get('lossBalance')
gridPoint = dict(learning_rate=lRate,lossWeights={'names':lBalance,'boxes':1-lBalance})

# %%
pp = Pipe(generatorParams=gParams,modelFunc=transferNET,
          modelName="ResNet50V2",modelParams=mParams)
pp.compiler(optim=Adam(),lrScheduleParams=lrParams,eStopParams=eSparams,
            trainabilityParams=trParams,gridPoint=gridPoint,sBest=True)
pp.fit(gridPoint=gridPoint,fitParams=fParams)
pp.evaluate()
pp.save()
pp.report()
# Out:
# imScanTrain: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 54.68it/s]
# imScanTest: 100%|██████████████████████████████████████████████████████████████████████████████████████████| 196/196 [00:03<00:00, 54.62it/s]
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 3s 0us/step
# 94683136/94668760 [==============================] - 3s 0us/step
# Epoch 1/30
# 2022-07-29 19:08:15.958722: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2022-07-29 19:08:17.609586: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - ETA: 0s - loss: 5.0007 - names_loss: 4.6182 - boxes_loss: 0.3825 - names_CategoricalAccuracy: 0.0737 - names_Precision: 0.3796 - names_Recall: 0.0056 - boxes_IoU: -0.0232
# 2022-07-29 19:10:24.048458: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 229/229 [==============================] - 145s 609ms/step - loss: 5.0007 - names_loss: 4.6182 - boxes_loss: 0.3825 - names_CategoricalAccuracy: 0.0737 - names_Precision: 0.3796 - names_Recall: 0.0056 - boxes_IoU: -0.0232 - val_loss: 3.8705 - val_names_loss: 3.7246 - val_boxes_loss: 0.1459 - val_names_CategoricalAccuracy: 0.1625 - val_names_Precision: 0.5000 - val_names_Recall: 0.0213 - val_boxes_IoU: 0.1322 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 144.5287
# Epoch 2/30
# 229/229 [==============================] - 142s 620ms/step - loss: 3.4367 - names_loss: 3.2893 - boxes_loss: 0.1474 - names_CategoricalAccuracy: 0.2310 - names_Precision: 0.6667 - names_Recall: 0.0319 - boxes_IoU: 0.2389 - val_loss: 3.3941 - val_names_loss: 3.3310 - val_boxes_loss: 0.0631 - val_names_CategoricalAccuracy: 0.2212 - val_names_Precision: 0.6346 - val_names_Recall: 0.0412 - val_boxes_IoU: 0.3160 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 141.3555
# Epoch 3/30
# 229/229 [==============================] - 143s 624ms/step - loss: 2.6325 - names_loss: 2.5691 - boxes_loss: 0.0634 - names_CategoricalAccuracy: 0.3693 - names_Precision: 0.7447 - names_Recall: 0.0999 - boxes_IoU: 0.3728 - val_loss: 3.0753 - val_names_loss: 3.0438 - val_boxes_loss: 0.0316 - val_names_CategoricalAccuracy: 0.2650 - val_names_Precision: 0.6228 - val_names_Recall: 0.0887 - val_boxes_IoU: 0.4920 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 142.7025
# Epoch 4/30
# 229/229 [==============================] - 142s 618ms/step - loss: 2.0690 - names_loss: 2.0316 - boxes_loss: 0.0375 - names_CategoricalAccuracy: 0.4829 - names_Precision: 0.8237 - names_Recall: 0.2033 - boxes_IoU: 0.4785 - val_loss: 3.1432 - val_names_loss: 3.1151 - val_boxes_loss: 0.0281 - val_names_CategoricalAccuracy: 0.2812 - val_names_Precision: 0.5946 - val_names_Recall: 0.1100 - val_boxes_IoU: 0.5107 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 141.7375
# Epoch 5/30
# 229/229 [==============================] - 142s 620ms/step - loss: 1.6450 - names_loss: 1.6164 - boxes_loss: 0.0286 - names_CategoricalAccuracy: 0.5796 - names_Precision: 0.8551 - names_Recall: 0.3206 - boxes_IoU: 0.5227 - val_loss: 2.9162 - val_names_loss: 2.8911 - val_boxes_loss: 0.0251 - val_names_CategoricalAccuracy: 0.2812 - val_names_Precision: 0.5622 - val_names_Recall: 0.1300 - val_boxes_IoU: 0.5318 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 141.7226
# Epoch 6/30
# 229/229 [==============================] - 142s 619ms/step - loss: 1.3507 - names_loss: 1.3264 - boxes_loss: 0.0243 - names_CategoricalAccuracy: 0.6509 - names_Precision: 0.8653 - names_Recall: 0.4181 - boxes_IoU: 0.5495 - val_loss: 3.1218 - val_names_loss: 3.1007 - val_boxes_loss: 0.0211 - val_names_CategoricalAccuracy: 0.2987 - val_names_Precision: 0.5018 - val_names_Recall: 0.1775 - val_boxes_IoU: 0.5624 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 141.7708
# Epoch 7/30
# 229/229 [==============================] - 141s 615ms/step - loss: 1.1168 - names_loss: 1.0952 - boxes_loss: 0.0216 - names_CategoricalAccuracy: 0.6998 - names_Precision: 0.8794 - names_Recall: 0.5106 - boxes_IoU: 0.5666 - val_loss: 2.9705 - val_names_loss: 2.9501 - val_boxes_loss: 0.0203 - val_names_CategoricalAccuracy: 0.3025 - val_names_Precision: 0.5206 - val_names_Recall: 0.1737 - val_boxes_IoU: 0.5662 - learning_rate: 0.0010 - Trainable: 15.0000 - lapTime: 140.7858
# Epoch 8/30
# 229/229 [==============================] - 143s 624ms/step - loss: 0.7333 - names_loss: 0.7127 - boxes_loss: 0.0205 - names_CategoricalAccuracy: 0.8233 - names_Precision: 0.9393 - names_Recall: 0.6670 - boxes_IoU: 0.5752 - val_loss: 2.5065 - val_names_loss: 2.4865 - val_boxes_loss: 0.0199 - val_names_CategoricalAccuracy: 0.4025 - val_names_Precision: 0.6357 - val_names_Recall: 0.2137 - val_boxes_IoU: 0.5717 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 142.5399
# Epoch 9/30
# 229/229 [==============================] - 142s 621ms/step - loss: 0.6069 - names_loss: 0.5868 - boxes_loss: 0.0201 - names_CategoricalAccuracy: 0.8616 - names_Precision: 0.9477 - names_Recall: 0.7271 - boxes_IoU: 0.5780 - val_loss: 2.4852 - val_names_loss: 2.4656 - val_boxes_loss: 0.0197 - val_names_CategoricalAccuracy: 0.3987 - val_names_Precision: 0.6604 - val_names_Recall: 0.2212 - val_boxes_IoU: 0.5726 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 141.9220
# Epoch 10/30
# 229/229 [==============================] - 143s 625ms/step - loss: 0.5404 - names_loss: 0.5206 - boxes_loss: 0.0199 - names_CategoricalAccuracy: 0.8818 - names_Precision: 0.9594 - names_Recall: 0.7550 - boxes_IoU: 0.5812 - val_loss: 2.4648 - val_names_loss: 2.4452 - val_boxes_loss: 0.0196 - val_names_CategoricalAccuracy: 0.4013 - val_names_Precision: 0.6810 - val_names_Recall: 0.2375 - val_boxes_IoU: 0.5756 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 142.7915
# Epoch 11/30
# 229/229 [==============================] - 143s 623ms/step - loss: 0.4936 - names_loss: 0.4737 - boxes_loss: 0.0200 - names_CategoricalAccuracy: 0.8957 - names_Precision: 0.9651 - names_Recall: 0.7848 - boxes_IoU: 0.5818 - val_loss: 2.4925 - val_names_loss: 2.4735 - val_boxes_loss: 0.0190 - val_names_CategoricalAccuracy: 0.3887 - val_names_Precision: 0.6444 - val_names_Recall: 0.2287 - val_boxes_IoU: 0.5803 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 142.7403
# Epoch 12/30
# 229/229 [==============================] - 143s 623ms/step - loss: 0.4699 - names_loss: 0.4505 - boxes_loss: 0.0194 - names_CategoricalAccuracy: 0.9060 - names_Precision: 0.9658 - names_Recall: 0.7938 - boxes_IoU: 0.5842 - val_loss: 2.4730 - val_names_loss: 2.4535 - val_boxes_loss: 0.0196 - val_names_CategoricalAccuracy: 0.3975 - val_names_Precision: 0.6409 - val_names_Recall: 0.2387 - val_boxes_IoU: 0.5735 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 142.9141
# Epoch 13/30
# 229/229 [==============================] - 143s 626ms/step - loss: 0.4256 - names_loss: 0.4064 - boxes_loss: 0.0192 - names_CategoricalAccuracy: 0.9187 - names_Precision: 0.9700 - names_Recall: 0.8215 - boxes_IoU: 0.5868 - val_loss: 2.4821 - val_names_loss: 2.4634 - val_boxes_loss: 0.0188 - val_names_CategoricalAccuracy: 0.3875 - val_names_Precision: 0.6044 - val_names_Recall: 0.2425 - val_boxes_IoU: 0.5804 - learning_rate: 1.0000e-04 - Trainable: 15.0000 - lapTime: 143.2758
# Epoch 14/30
# 229/229 [==============================] - 144s 628ms/step - loss: 0.3928 - names_loss: 0.3737 - boxes_loss: 0.0191 - names_CategoricalAccuracy: 0.9260 - names_Precision: 0.9744 - names_Recall: 0.8304 - boxes_IoU: 0.5856 - val_loss: 2.4700 - val_names_loss: 2.4510 - val_boxes_loss: 0.0190 - val_names_CategoricalAccuracy: 0.4062 - val_names_Precision: 0.6159 - val_names_Recall: 0.2425 - val_boxes_IoU: 0.5794 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 143.6544
# Epoch 15/30
# 229/229 [==============================] - 143s 623ms/step - loss: 0.3890 - names_loss: 0.3700 - boxes_loss: 0.0190 - names_CategoricalAccuracy: 0.9277 - names_Precision: 0.9732 - names_Recall: 0.8412 - boxes_IoU: 0.5876 - val_loss: 2.4756 - val_names_loss: 2.4568 - val_boxes_loss: 0.0187 - val_names_CategoricalAccuracy: 0.3987 - val_names_Precision: 0.6171 - val_names_Recall: 0.2437 - val_boxes_IoU: 0.5810 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 143.2100
# Epoch 16/30
# 229/229 [==============================] - 144s 631ms/step - loss: 0.3876 - names_loss: 0.3685 - boxes_loss: 0.0192 - names_CategoricalAccuracy: 0.9260 - names_Precision: 0.9747 - names_Recall: 0.8403 - boxes_IoU: 0.5877 - val_loss: 2.4751 - val_names_loss: 2.4563 - val_boxes_loss: 0.0188 - val_names_CategoricalAccuracy: 0.4000 - val_names_Precision: 0.6238 - val_names_Recall: 0.2488 - val_boxes_IoU: 0.5802 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 144.4259
# Epoch 17/30
# 229/229 [==============================] - 145s 632ms/step - loss: 0.3857 - names_loss: 0.3668 - boxes_loss: 0.0189 - names_CategoricalAccuracy: 0.9266 - names_Precision: 0.9744 - names_Recall: 0.8421 - boxes_IoU: 0.5880 - val_loss: 2.4571 - val_names_loss: 2.4383 - val_boxes_loss: 0.0188 - val_names_CategoricalAccuracy: 0.4062 - val_names_Precision: 0.6270 - val_names_Recall: 0.2500 - val_boxes_IoU: 0.5818 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 144.4309
# Epoch 18/30
# 229/229 [==============================] - 143s 623ms/step - loss: 0.3714 - names_loss: 0.3526 - boxes_loss: 0.0189 - names_CategoricalAccuracy: 0.9341 - names_Precision: 0.9751 - names_Recall: 0.8491 - boxes_IoU: 0.5887 - val_loss: 2.4732 - val_names_loss: 2.4544 - val_boxes_loss: 0.0188 - val_names_CategoricalAccuracy: 0.3987 - val_names_Precision: 0.6219 - val_names_Recall: 0.2488 - val_boxes_IoU: 0.5804 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 142.5876
# Epoch 19/30
# 229/229 [==============================] - ETA: 0s - loss: 0.3689 - names_loss: 0.3501 - boxes_loss: 0.0188 - names_CategoricalAccuracy: 0.9341 - names_Precision: 0.9758 - names_Recall: 0.8525 - boxes_IoU: 0.5905
#
# ---------------------------------------------------------------
# eStop initiated after epoch  18 for poor loss gradient of 0.148
# ---------------------------------------------------------------
#
# 229/229 [==============================] - 147s 641ms/step - loss: 0.3689 - names_loss: 0.3501 - boxes_loss: 0.0188 - names_CategoricalAccuracy: 0.9341 - names_Precision: 0.9758 - names_Recall: 0.8525 - boxes_IoU: 0.5905 - val_loss: 2.4841 - val_names_loss: 2.4654 - val_boxes_loss: 0.0187 - val_names_CategoricalAccuracy: 0.4000 - val_names_Precision: 0.6173 - val_names_Recall: 0.2500 - val_boxes_IoU: 0.5822 - learning_rate: 1.0000e-05 - Trainable: 15.0000 - lapTime: 146.8379
#
# ----------
# EVALUATION
# ----------
#
# 254/254 [==============================] - 146s 575ms/step - loss: 0.3694 - names_loss: 0.3509 - boxes_loss: 0.0185 - names_CategoricalAccuracy: 0.9358 - names_Precision: 0.9815 - names_Recall: 0.9125 - boxes_IoU: 0.5872
# 251/251 [==============================] - 143s 570ms/step - loss: 2.4809 - names_loss: 2.4624 - boxes_loss: 0.0185 - names_CategoricalAccuracy: 0.4090 - names_Precision: 0.6575 - names_Recall: 0.2591 - boxes_IoU: 0.5893
# 2022-07-29 19:58:28.063436: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# INFO:tensorflow:Assets written to: ./deployables/ResNet50V2/ResNet50V2/tfsave/assets
#          name target_size batch_size optimizer patience slope factor  \
# 0  ResNet50V2  (224, 224)         32      Adam       15  0.15    0.1
#
#   learning_rate                   lossWeights epochs verbose  \
# 0         0.001  {'names': 0.5, 'boxes': 0.5}     30       1
#
#                                                 logs      loss names_loss  \
# 0  {'loss': [5.000739574432373, 3.436673164367676...  0.369423   0.350934
#
#   boxes_loss names_CategoricalAccuracy names_Precision names_Recall boxes_IoU  \
# 0   0.018489                  0.935778        0.981474     0.912525  0.587236
#
#    val_loss val_names_loss val_boxes_loss val_names_CategoricalAccuracy  \
# 0  2.480897       2.462386       0.018511                      0.408989
#
#   val_names_Precision val_names_Recall val_boxes_IoU
# 0            0.657504         0.259089      0.589307
# ----------
# PREDICTION
# ----------
# 2022-07-29 19:58:39.644274: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 254/254 [==============================] - 141s 555ms/step
# 251/251 [==============================] - 138s 549ms/step
# samples from TRAINING SET
# samples from TESTING SET
